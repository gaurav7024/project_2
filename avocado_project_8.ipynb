# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("avocado.csv")

# %%
df.shape
# Out:
# (1517, 14)

# %%
df
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume      4046       4225  \
# 0              0  27-12-2015          1.33      64236.62   1036.74   54454.85
# 1              1  20-12-2015          1.35      54876.98    674.28   44638.81
# 2              2  13-12-2015          0.93     118220.22    794.70  109149.67
# 3              3  06-12-2015          1.08      78992.15   1132.00   71976.41
# 4              4  29-11-2015          1.28      51039.60    941.48   43838.39
# ...          ...         ...           ...           ...       ...        ...
# 1512          10  16-10-2016          1.39     190846.01  57529.11   56366.66
# 1513          11  09-10-2016          1.51     178235.75  43325.87   52189.61
# 1514          12  02-10-2016          1.48     178410.82  46364.75   52893.38
# 1515          13  25-09-2016          1.47     189131.52  54110.79   53593.58
# 1516          14  18-09-2016          1.43     182978.30  43116.41   54193.42
#
#           4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0        48.16     8696.87     8603.62       93.25         0.00  conventional
# 1        58.33     9505.56     9408.07       97.49         0.00  conventional
# 2       130.50     8145.35     8042.21      103.14         0.00  conventional
# 3        72.58     5811.16     5677.40      133.76         0.00  conventional
# 4        75.78     6183.95     5986.26      197.69         0.00  conventional
# ...        ...         ...         ...         ...          ...           ...
# 1512  17531.78    59418.46    48823.53    10354.65       240.28  conventional
# 1513  19419.57    63300.70    54704.14     8596.56         0.00  conventional
# 1514  16736.92    62415.77    53332.61     8258.16       825.00  conventional
# 1515  17495.42    63931.73    55653.47     8278.26         0.00  conventional
# 1516  16563.91    69104.56    57456.21    11648.35         0.00  conventional
#
#       year     region
# 0     2015     Albany
# 1     2015     Albany
# 2     2015     Albany
# 3     2015     Albany
# 4     2015     Albany
# ...    ...        ...
# 1512  2016  Charlotte
# 1513  2016  Charlotte
# 1514  2016  Charlotte
# 1515  2016  Charlotte
# 1516  2016  Charlotte
#
# [1517 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
df
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume      4046       4225  \
# 0              0  27-12-2015          1.33      64236.62   1036.74   54454.85
# 1              1  20-12-2015          1.35      54876.98    674.28   44638.81
# 2              2  13-12-2015          0.93     118220.22    794.70  109149.67
# 3              3  06-12-2015          1.08      78992.15   1132.00   71976.41
# 4              4  29-11-2015          1.28      51039.60    941.48   43838.39
# ...          ...         ...           ...           ...       ...        ...
# 1512          10  16-10-2016          1.39     190846.01  57529.11   56366.66
# 1513          11  09-10-2016          1.51     178235.75  43325.87   52189.61
# 1514          12  02-10-2016          1.48     178410.82  46364.75   52893.38
# 1515          13  25-09-2016          1.47     189131.52  54110.79   53593.58
# 1516          14  18-09-2016          1.43     182978.30  43116.41   54193.42
#
#           4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0        48.16     8696.87     8603.62       93.25         0.00  conventional
# 1        58.33     9505.56     9408.07       97.49         0.00  conventional
# 2       130.50     8145.35     8042.21      103.14         0.00  conventional
# 3        72.58     5811.16     5677.40      133.76         0.00  conventional
# 4        75.78     6183.95     5986.26      197.69         0.00  conventional
# ...        ...         ...         ...         ...          ...           ...
# 1512  17531.78    59418.46    48823.53    10354.65       240.28  conventional
# 1513  19419.57    63300.70    54704.14     8596.56         0.00  conventional
# 1514  16736.92    62415.77    53332.61     8258.16       825.00  conventional
# 1515  17495.42    63931.73    55653.47     8278.26         0.00  conventional
# 1516  16563.91    69104.56    57456.21    11648.35         0.00  conventional
#
#       year     region
# 0     2015     Albany
# 1     2015     Albany
# 2     2015     Albany
# 3     2015     Albany
# 4     2015     Albany
# ...    ...        ...
# 1512  2016  Charlotte
# 1513  2016  Charlotte
# 1514  2016  Charlotte
# 1515  2016  Charlotte
# 1516  2016  Charlotte
#
# [1517 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1517 entries, 0 to 1516
# Data columns (total 14 columns):
# Unnamed: 0      1517 non-null int64
# Date            1517 non-null object
# AveragePrice    1517 non-null float64
# Total Volume    1517 non-null float64
# 4046            1517 non-null float64
# 4225            1517 non-null float64
# 4770            1517 non-null float64
# Total Bags      1517 non-null float64
# Small Bags      1517 non-null float64
# Large Bags      1517 non-null float64
# XLarge Bags     1517 non-null float64
# type            1517 non-null object
# year            1517 non-null int64
# region          1517 non-null object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 166.0+ KB

# %%
df.keys()
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
df.describe()
# Out:
#         Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  1517.000000   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03
# mean     26.995386      1.074990  1.601879e+06  6.464387e+05  6.114375e+05
# std      14.848287      0.188891  4.433143e+06  1.947614e+06  1.672906e+06
# min       0.000000      0.490000  3.875074e+04  4.677200e+02  1.783770e+03
# 25%      14.000000      0.980000  1.474700e+05  2.040034e+04  4.147606e+04
# 50%      29.000000      1.080000  4.027919e+05  8.175117e+04  1.186649e+05
# 75%      39.000000      1.190000  9.819751e+05  3.775785e+05  4.851503e+05
# max      51.000000      1.680000  4.465546e+07  1.893304e+07  1.895648e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000
# mean   5.040550e+04  2.935974e+05  2.487736e+05  4.264205e+04    2181.771074
# std    1.377812e+05  7.579765e+05  6.474765e+05  1.182157e+05    7455.712144
# min    0.000000e+00  3.311770e+03  3.311770e+03  0.000000e+00       0.000000
# 25%    9.112500e+02  3.620689e+04  2.972722e+04  5.407400e+02       0.000000
# 50%    7.688170e+03  7.397906e+04  6.237569e+04  5.044350e+03       0.000000
# 75%    2.916730e+04  1.576097e+05  1.461994e+05  2.926767e+04     401.480000
# max    1.381516e+06  6.736304e+06  5.893642e+06  1.121076e+06  108072.790000
#
#               year
# count  1517.000000
# mean   2015.162821
# std       0.369324
# min    2015.000000
# 25%    2015.000000
# 50%    2015.000000
# 75%    2015.000000
# max    2016.000000

# %%
sns.heatmap(df.isnull())

# %%
f,ax = plt.subplots(figsize=(10, 10))
sns.heatmap(df.corr(), annot=True, linewidths=.4, fmt= '.3f',ax=ax)
plt.show()

# %%
region_list=list(df.region.unique())
average_price=[]

for i in region_list:
    x=df[df.region==i]
    region_average=sum(x.AveragePrice)/len(x)
    average_price.append(region_average)

df1=pd.DataFrame({'region_list':region_list,'average_price':average_price})
new_index=df1.average_price.sort_values(ascending=False).index.values
sorted_data=df1.reindex(new_index)

plt.figure(figsize=(24,10))
ax=sns.barplot(x=sorted_data.region_list,y=sorted_data.average_price)

plt.xticks(rotation=90)
plt.xlabel('Region')
plt.ylabel('Average Price')
plt.title('Average Price of Avocado According to Region')
# Out:
# Text(0.5, 1.0, 'Average Price of Avocado According to Region')

# %%
sns.set(font_scale=1.5) 
from scipy.stats import norm
fig, ax = plt.subplots(figsize=(15, 9))
sns.distplot(a=df.AveragePrice, kde=False, fit=norm)

# %%
plt.figure(figsize=(18,10))
sns.lineplot(x="Date", y="AveragePrice", hue='type', data=df)
plt.show()

# %%
filter1=df.region!='TotalUS'
df1=df[filter1]

region_list=list(df1.region.unique())
average_total_volume=[]

for i in region_list:
    x=df1[df1.region==i]
    average_total_volume.append(sum(x['Total Volume'])/len(x))
df3=pd.DataFrame({'region_list':region_list,'average_total_volume':average_total_volume})

new_index=df3.average_total_volume.sort_values(ascending=False).index.values
sorted_data1=df3.reindex(new_index)

plt.figure(figsize=(22,10))
ax=sns.barplot(x=sorted_data1.region_list,y=sorted_data1.average_total_volume)

plt.xticks(rotation=90)
plt.xlabel('Region')
plt.ylabel('Average of Total Volume')
plt.title('Average of Total Volume According to Region')
# Out:
# Text(0.5, 1.0, 'Average of Total Volume According to Region')

# %%
g = sns.factorplot('AveragePrice','region',data=df,
                   hue='year',
                   size=18,
                   aspect=0.7,
                   palette='Blues',
                   join=False,
              )
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  27-12-2015          1.33      64236.62  1036.74   54454.85   48.16
# 1  20-12-2015          1.35      54876.98   674.28   44638.81   58.33
# 2  13-12-2015          0.93     118220.22   794.70  109149.67  130.50
# 3  06-12-2015          1.08      78992.15  1132.00   71976.41   72.58
# 4  29-11-2015          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
df['Total Volume'].value_counts()
# Out:
# 453631.25     1
# 198395.76     1
# 63902.90      1
# 592588.01     1
# 63608.01      1
#              ..
# 83453.76      1
# 202831.97     1
# 1352027.64    1
# 435210.71     1
# 212091.14     1
# Name: Total Volume, Length: 1517, dtype: int64

# %%
df['AveragePrice'].value_counts()
# Out:
# 1.08    46
# 0.99    44
# 1.03    44
# 1.09    43
# 1.10    43
#         ..
# 1.61     1
# 1.66     1
# 1.60     1
# 0.64     1
# 1.64     1
# Name: AveragePrice, Length: 113, dtype: int64

# %%
df['Date'].value_counts()
# Out:
# 05-04-2015    34
# 12-04-2015    34
# 19-04-2015    33
# 26-04-2015    32
# 29-03-2015    32
#               ..
# 03-07-2016     3
# 31-07-2016     3
# 07-08-2016     3
# 24-07-2016     3
# 11-09-2016     2
# Name: Date, Length: 104, dtype: int64

# %%
df['Date'].head(2)
# Out:
# 0    27-12-2015
# 1    20-12-2015
# Name: Date, dtype: object

# %%
df['Date_day']=df['Date'].str.split('-').str[0].astype(int)
df['Date_month']=df['Date'].str.split('-').str[1].astype(int)
#df['Date_year']=df['Date'].str.split('-').str[2].astype(int)

# %%
df.drop(['Date'],axis=1,inplace=True)

# %%
df['type'].value_counts()
# Out:
# conventional    1517
# Name: type, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['type']=le.fit_transform(df['type'])

# %%
df['region'].value_counts()
# Out:
# California             76
# Albany                 67
# BaltimoreWashington    65
# Boise                  65
# Boston                 62
# Atlanta                54
# PhoenixTucson          52
# BuffaloRochester       51
# Spokane                49
# Columbus               47
# NewYork                44
# Jacksonville           41
# Detroit                40
# SouthCentral           39
# SanDiego               38
# West                   36
# Louisville             34
# Tampa                  34
# Charlotte              31
# Portland               30
# NorthernNewEngland     29
# Houston                29
# WestTexNewMexico       27
# TotalUS                25
# Nashville              25
# SouthCarolina          24
# Denver                 24
# GrandRapids            23
# Chicago                23
# Pittsburgh             22
# Orlando                21
# RichmondNorfolk        21
# Syracuse               19
# HarrisburgScranton     19
# GreatLakes             18
# Midsouth               18
# Roanoke                17
# DallasFtWorth          17
# MiamiFtLauderdale      17
# Indianapolis           16
# RaleighGreensboro      16
# StLouis                16
# SanFrancisco           15
# HartfordSpringfield    13
# Philadelphia           13
# Plains                 12
# Northeast              12
# LasVegas               10
# Seattle                 9
# Southeast               9
# LosAngeles              3
# Name: region, dtype: int64

# %%
df['region']=le.fit_transform(df['region'])

# %%
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {dtype('int32'): Index(['type', 'region', 'Date_day', 'Date_month'], dtype='object'),
#  dtype('int64'): Index(['year'], dtype='object'),
#  dtype('float64'): Index(['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags',
#         'Small Bags', 'Large Bags', 'XLarge Bags'],
#        dtype='object')}

# %%
df_int=df.select_dtypes(include=[np.number])
df_int.head(50)
# Out:
#     AveragePrice  Total Volume     4046       4225     4770  Total Bags  \
# 0           1.33      64236.62  1036.74   54454.85    48.16     8696.87
# 1           1.35      54876.98   674.28   44638.81    58.33     9505.56
# 2           0.93     118220.22   794.70  109149.67   130.50     8145.35
# 3           1.08      78992.15  1132.00   71976.41    72.58     5811.16
# 4           1.28      51039.60   941.48   43838.39    75.78     6183.95
# 5           1.26      55979.78  1184.27   48067.99    43.61     6683.91
# 6           0.99      83453.76  1368.92   73672.72    93.26     8318.86
# 7           0.98     109428.33   703.75  101815.36    80.00     6829.22
# 8           1.02      99811.42  1022.15   87315.57    85.34    11388.36
# 9           1.07      74338.76   842.40   64757.44   113.00     8625.92
# 10          1.12      84843.44   924.86   75595.85   117.07     8205.66
# 11          1.28      64489.17  1582.03   52677.92   105.32    10123.90
# 12          1.31      61007.10  2268.32   49880.67   101.36     8756.75
# 13          0.99     106803.39  1204.88   99409.21   154.84     6034.46
# 14          1.33      69759.01  1028.03   59313.12   150.50     9267.36
# 15          1.28      76111.27   985.73   65696.86   142.00     9286.68
# 16          1.11      99172.96   879.45   90062.62   240.79     7990.10
# 17          1.07     105693.84   689.01   94362.67   335.43    10306.73
# 18          1.34      79992.09   733.16   67933.79   444.78    10880.36
# 19          1.33      80043.78   539.65   68666.01   394.90    10443.22
# 20          1.12     111140.93   584.63  100961.46   368.95     9225.89
# 21          1.45      75133.10   509.94   62035.06   741.08    11847.02
# 22          1.11     106757.10   648.75   91949.05   966.61    13192.69
# 23          1.26      96617.00  1042.10   82049.40  2238.02    11287.48
# 24          1.05     124055.31   672.25   94693.52  4257.64    24431.90
# 25          1.35     109252.12   869.45   72600.55  5883.16    29898.96
# 26          1.37      89534.81   664.23   57545.79  4662.71    26662.08
# 27          1.27     104849.39   804.01   76688.55  5481.18    21875.65
# 28          1.32      89631.30   850.58   55400.94  4377.19    29002.59
# 29          1.07     122743.06   656.71   99220.82    90.32    22775.21
# 30          1.23      95123.62   922.37   70469.69    50.55    23681.01
# 31          1.19     101470.91   680.27   71376.81    58.70    29355.13
# 32          1.43     109857.47  1150.55   81955.16    94.32    26657.44
# 33          1.26     120427.91  1420.43  102000.52   185.66    16821.30
# 34          1.20      59197.67   919.87   45490.05   217.24    12570.51
# 35          1.22      49585.46   875.65   35841.75    89.62    12778.44
# 36          1.19      49064.73   774.15   33941.51    47.15    14301.92
# 37          1.13      48364.29   864.27   30374.15    21.50    17104.37
# 38          1.16      47362.13   961.77   35577.66    93.76    10728.94
# 39          1.02      67799.08  1402.28   58623.22    89.50     7684.08
# 40          1.12      46346.85  2141.83   34313.56   141.80     9749.66
# 41          1.11      43045.79  2128.26   30447.17    99.67    10370.69
# 42          1.07      40507.36   795.68   30370.64   159.05     9181.99
# 43          0.99      55595.74   629.46   45633.34   181.49     9151.45
# 44          1.07      45675.05  1088.38   35056.13   151.00     9379.54
# 45          1.06      41567.62   986.66   30045.51   222.42    10313.03
# 46          0.99      51253.97  1357.37   39111.81   163.25    10621.54
# 47          0.99      70873.60  1353.90   60017.20   179.32     9323.18
# 48          1.06      45147.50   941.38   33196.16   164.14    10845.82
# 49          1.17      44511.28   914.14   31540.32   135.77    11921.05
#
#     Small Bags  Large Bags  XLarge Bags  type  year  region  Date_day  \
# 0      8603.62       93.25         0.00     0  2015       0        27
# 1      9408.07       97.49         0.00     0  2015       0        20
# 2      8042.21      103.14         0.00     0  2015       0        13
# 3      5677.40      133.76         0.00     0  2015       0         6
# 4      5986.26      197.69         0.00     0  2015       0        29
# 5      6556.47      127.44         0.00     0  2015       0        22
# 6      8196.81      122.05         0.00     0  2015       0        15
# 7      6266.85      562.37         0.00     0  2015       0         8
# 8     11104.53      283.83         0.00     0  2015       0         1
# 9      8061.47      564.45         0.00     0  2015       0        25
# 10     7877.86      327.80         0.00     0  2015       0        18
# 11     9866.27      257.63         0.00     0  2015       0        11
# 12     8379.98      376.77         0.00     0  2015       0         4
# 13     5888.87      145.59         0.00     0  2015       0        27
# 14     8489.10      778.26         0.00     0  2015       0        20
# 15     8665.19      621.49         0.00     0  2015       0        13
# 16     7762.87      227.23         0.00     0  2015       0         6
# 17    10218.93       87.80         0.00     0  2015       0        30
# 18    10745.79      134.57         0.00     0  2015       0        23
# 19    10297.68      145.54         0.00     0  2015       0        16
# 20     9116.34      109.55         0.00     0  2015       0         9
# 21    11768.52       78.50         0.00     0  2015       0         2
# 22    13061.53      131.16         0.00     0  2015       0        26
# 23    11103.49      183.99         0.00     0  2015       0        19
# 24    24290.08      108.49        33.33     0  2015       0        12
# 25    29663.19      235.77         0.00     0  2015       0         5
# 26    26311.76      350.32         0.00     0  2015       0        28
# 27    21662.00      213.65         0.00     0  2015       0        21
# 28    28343.14      659.45         0.00     0  2015       0        14
# 29    22314.99      460.22         0.00     0  2015       0         7
# 30    23222.49      458.52         0.00     0  2015       0        31
# 31    28761.81      593.32         0.00     0  2015       0        24
# 32    26285.43      372.01         0.00     0  2015       0        17
# 33    16535.55      285.75         0.00     0  2015       0        10
# 34    12201.95      368.56         0.00     0  2015       0         3
# 35    12076.83      701.61         0.00     0  2015       0        26
# 36    13602.97      698.95         0.00     0  2015       0        19
# 37    16438.49      665.88         0.00     0  2015       0        12
# 38     9869.16      755.61       104.17     0  2015       0         5
# 39     7208.49      475.59         0.00     0  2015       0        29
# 40     9252.60      497.06         0.00     0  2015       0        22
# 41     9989.59      381.10         0.00     0  2015       0        15
# 42     8827.55      354.44         0.00     0  2015       0         8
# 43     8986.06      165.39         0.00     0  2015       0         1
# 44     9000.16      379.38         0.00     0  2015       0        22
# 45     9979.87      333.16         0.00     0  2015       0        15
# 46    10113.10      508.44         0.00     0  2015       0         8
# 47     9170.82      152.36         0.00     0  2015       0         1
# 48    10103.35      742.47         0.00     0  2015       0        25
# 49    11651.09      269.96         0.00     0  2015       0        18
#
#     Date_month
# 0           12
# 1           12
# 2           12
# 3           12
# 4           11
# 5           11
# 6           11
# 7           11
# 8           11
# 9           10
# 10          10
# 11          10
# 12          10
# 13           9
# 14           9
# 15           9
# 16           9
# 17           8
# 18           8
# 19           8
# 20           8
# 21           8
# 22           7
# 23           7
# 24           7
# 25           7
# 26           6
# 27           6
# 28           6
# 29           6
# 30           5
# 31           5
# 32           5
# 33           5
# 34           5
# 35           4
# 36           4
# 37           4
# 38           4
# 39           3
# 40           3
# 41           3
# 42           3
# 43           3
# 44           2
# 45           2
# 46           2
# 47           2
# 48           1
# 49           1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1517 entries, 0 to 1516
# Data columns (total 14 columns):
# AveragePrice    1517 non-null float64
# Total Volume    1517 non-null float64
# 4046            1517 non-null float64
# 4225            1517 non-null float64
# 4770            1517 non-null float64
# Total Bags      1517 non-null float64
# Small Bags      1517 non-null float64
# Large Bags      1517 non-null float64
# XLarge Bags     1517 non-null float64
# type            1517 non-null int32
# year            1517 non-null int64
# region          1517 non-null int32
# Date_day        1517 non-null int32
# Date_month      1517 non-null int32
# dtypes: float64(9), int32(4), int64(1)
# memory usage: 142.3 KB

# %%
df.shape
# Out:
# (1517, 14)

# %%
f,ax = plt.subplots(figsize=(19, 10))
sns.heatmap(df.corr(), annot=True, linewidths=.4, fmt= '.3f',ax=ax)
plt.show()

# %%
df.skew()
# Out:
# AveragePrice   -0.109444
# Total Volume    6.200138
# 4046            6.051830
# 4225            6.394926
# 4770            5.405164
# Total Bags      5.366378
# Small Bags      5.355185
# Large Bags      5.144495
# XLarge Bags     5.775077
# type            0.000000
# year            1.828332
# region          0.288146
# Date_day        0.027740
# Date_month      0.233418
# dtype: float64

# %%
df.skew()
for col in df.skew().index:
    if col in df:
        if df.skew().loc[col]>0.5:
            df[col]=np.sqrt(df[col])
        if df.skew().loc[col]<-0.5:
            df[col]=np.cbrt(df[col])

# %%
#Lets again chcek the skewness
for col in df.skew().index:
    if col in df:
        print("Skewness of column {} is: {}".format(col,df.skew().loc[col]/1/4))
# Out:
# Skewness of column AveragePrice is: -0.027360948099990578
# Skewness of column Total Volume is: 0.7823399492540906
# Skewness of column 4046 is: 0.720846251381467
# Skewness of column 4225 is: 0.7229027546341933
# Skewness of column 4770 is: 0.6328256353786115
# Skewness of column Total Bags is: 0.73791912704967
# Skewness of column Small Bags is: 0.7390417315538523
# Skewness of column Large Bags is: 0.6292911686423796
# Skewness of column XLarge Bags is: 0.7291651461299495
# Skewness of column type is: 0.0
# Skewness of column year is: 0.4570829938086023
# Skewness of column region is: 0.07203655998090663
# Skewness of column Date_day is: 0.006934972921876089
# Skewness of column Date_month is: 0.05835455772867079

# %%
sns.set(font_scale=1.5) 
from scipy.stats import norm
fig, ax = plt.subplots(figsize=(15, 9))
sns.distplot(a=df.AveragePrice, kde=False, fit=norm)

# %%
plt.figure(figsize=(18,10))
sns.lineplot(x="Date_month", y="AveragePrice", hue='type', data=df)
plt.show()

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),cmap='coolwarm',annot=True)

# %%
df['region'].nunique()
# Out:
# 51

# %%
df['type'].nunique()
# Out:
# 1

# %%
#df.drop('type',axis=1,inplace=True)
#df_final=pd.get_dummies(df.drop(['region'],axis=1),drop_first=True)

# %%
df
# Out:
#       AveragePrice  Total Volume        4046        4225        4770  \
# 0             1.33    253.449443   32.198447  233.355630    6.939741
# 1             1.35    234.258362   25.966902  211.278986    7.637408
# 2             0.93    343.831674   28.190424  330.378071   11.423660
# 3             1.08    281.055422   33.645208  268.284196    8.519390
# 4             1.28    225.919455   30.683546  209.376193    8.705171
# ...            ...           ...         ...         ...         ...
# 1512          1.39    436.859257  239.852267  237.416638  132.407628
# 1513          1.51    422.179760  208.148673  228.450454  139.354117
# 1514          1.48    422.387050  215.324755  229.985608  129.371249
# 1515          1.47    434.892538  232.617261  231.502873  132.270254
# 1516          1.43    427.759629  207.644913  232.794802  128.700855
#
#       Total Bags  Small Bags  Large Bags  XLarge Bags  type       year  \
# 0      93.257010   92.755701    9.656604     0.000000     0  44.888751
# 1      97.496461   96.995206    9.873702     0.000000     0  44.888751
# 2      90.251593   89.678370   10.155787     0.000000     0  44.888751
# 3      76.230965   75.348524   11.565466     0.000000     0  44.888751
# 4      78.638095   77.370925   14.060228     0.000000     0  44.888751
# ...          ...         ...         ...          ...   ...        ...
# 1512  243.759020  220.960472  101.757801    15.500968     0  44.899889
# 1513  251.596304  233.889162   92.717636     0.000000     0  44.899889
# 1514  249.831483  230.938542   90.874419    28.722813     0  44.899889
# 1515  252.847246  235.909877   90.984944     0.000000     0  44.899889
# 1516  262.877462  239.700250  107.927522     0.000000     0  44.899889
#
#       region  Date_day  Date_month
# 0          0        27          12
# 1          0        20          12
# 2          0        13          12
# 3          0         6          12
# 4          0        29          11
# ...      ...       ...         ...
# 1512       7        16          10
# 1513       7         9          10
# 1514       7         2          10
# 1515       7        25           9
# 1516       7        18           9
#
# [1517 rows x 14 columns]

# %%
from sklearn.preprocessing import StandardScaler
x=df.drop(['AveragePrice'],axis=1)
y=df.AveragePrice

# %%
convert=StandardScaler()
x=convert.fit_transform(x)

# %%
x.shape,y.shape
# Out:
# ((1517, 13), (1517,))

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
pred=lr.predict(x_test)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 0.11969505155749517
# MSE: 0.023501512449954208
# RMSE: 0.15330203015601002

# %%
plt.scatter(x=y_test,y=pred)

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred=dtr.predict(x_test)

# %%
plt.scatter(x=y_test,y=pred)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 0.07187500000000001
# MSE: 0.010789802631578948
# RMSE: 0.10387397475584993

# %%
from sklearn.ensemble import RandomForestRegressor
rdr = RandomForestRegressor()
rdr.fit(x_train,y_train)
pred=rdr.predict(x_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 0.06176315789473684
# MSE: 0.006979282894736842
# RMSE: 0.0835421025276288

# %%
sns.distplot((y_test-pred),bins=50)

# %%
data = pd.DataFrame({'Y Test':y_test , 'Pred':pred},columns=['Y Test','Pred'])
sns.lmplot(x='Y Test',y='Pred',data=data,palette='rainbow')
data.head()
# Out:
#       Y Test   Pred
# 724     1.18  1.097
# 812     1.25  1.218
# 1466    1.08  1.055
# 1469    1.07  1.152
# 51      1.22  1.191

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=442)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
from sklearn.model_selection import cross_val_score,cross_val_predict

# %%
def model(a):
    ML=a
    ML.fit(x_train,y_train)
    pre=ML.predict(x_test)
    score=cross_val_score(a,x,y,cv=3)
    b=score.mean()
    return(print('Taining_score = ',ML.score(x_train,y_train),'\ncross_val_score = ',b,'\nR2_score = ',r2_score(y_test,pre),'\nMAE = ',mean_absolute_error(y_test,pre),'\nMSE = ',mean_squared_error(y_test,pre),'\nRMSE = ',np.sqrt(mean_squared_error(y_test,pre))))

# %%
from sklearn.linear_model import LinearRegression
model(LinearRegression())
# Out:
# Taining_score =  0.32776608186534517
# cross_val_score =  -4.631995220755967e+18
# R2_score =  0.24336152551316625
# MAE =  0.11339859204388388
# MSE =  0.022759697757275713
# RMSE =  0.1508631756170992

# %%
from sklearn.linear_model import Lasso
model(Lasso())
# Out:
# Taining_score =  0.0
# cross_val_score =  -0.008796381756158933
# R2_score =  -8.253446219663729e-05
# MAE =  0.12921909576083654
# MSE =  0.03008249908534877
# RMSE =  0.17344307159799946

# %%
from sklearn.linear_model import Ridge
model(Ridge())
# Out:
# Taining_score =  0.3226128242004307
# cross_val_score =  -0.02925566307172049
# R2_score =  0.23683472570533792
# MAE =  0.11391717303298705
# MSE =  0.022956024002843866
# RMSE =  0.15151245494296456

# %%
from sklearn.linear_model import ElasticNet
model(ElasticNet())
# Out:
# Taining_score =  0.0
# cross_val_score =  -0.008796381756158933
# R2_score =  -8.253446219663729e-05
# MAE =  0.12921909576083654
# MSE =  0.03008249908534877
# RMSE =  0.17344307159799946

# %%
from sklearn.neighbors import KNeighborsRegressor
model(KNeighborsRegressor())
# Out:
# Taining_score =  0.808430583171438
# cross_val_score =  0.07422057688526203
# R2_score =  0.6856165982726992
# MAE =  0.07347368421052632
# MSE =  0.009456657894736842
# RMSE =  0.09724534896197783

# %%
from sklearn.tree import DecisionTreeRegressor
model(DecisionTreeRegressor())
# Out:
# Taining_score =  1.0
# cross_val_score =  -0.24029774582565697
# R2_score =  0.6426198762620533
# MAE =  0.07019736842105262
# MSE =  0.010749999999999997
# RMSE =  0.10368220676663858

# %%
from sklearn.ensemble import GradientBoostingRegressor
model(GradientBoostingRegressor())
# Out:
# Taining_score =  0.8640483562606492
# cross_val_score =  0.29752045517779163
# R2_score =  0.7353405620732467
# MAE =  0.06750622603675191
# MSE =  0.007960960245788023
# RMSE =  0.08922421333801729

# %%
from sklearn.ensemble import RandomForestRegressor
model(RandomForestRegressor())
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Taining_score =  0.9577805678584983
# cross_val_score =  0.18258652202463813
# R2_score =  0.7500697973879974
# MAE =  0.06050328947368421
# MSE =  0.0075179046052631605
# RMSE =  0.08670585104399334

# %%
models=[]
models.append(('LinearRegression',LinearRegression()))
models.append(('Lasso',Lasso()))
models.append(('Ridge',Ridge()))
models.append(('ElasticNet',ElasticNet()))
models.append(('DecisionTreeRegressor',DecisionTreeRegressor()))
models.append(('KNeighborsRegressor',KNeighborsRegressor()))
models.append(('GradientBoostingRegressor',GradientBoostingRegressor()))
models.append(('RandomForestRegressor',RandomForestRegressor()))

# %%
from sklearn.model_selection import KFold,cross_val_score

# %%
ModelName = []
MSE = []
R2score =[]
cvs=[]
MAE = []
for name, model in models:
    model.fit(x_train,y_train)
    y_pred = model.predict(x_test)
    MSE.append(mean_squared_error(y_test, y_pred))
    R2score.append(r2_score(y_test,y_pred))
    MAE.append(mean_absolute_error(y_test,y_pred))
    kfold = KFold(n_splits=10, random_state=10) 
    re = cross_val_score(model, x, y, cv=kfold, scoring='r2').mean()
    cvs.append(re)
    ModelName.append(name)
result = pd.DataFrame({'Model_name': ModelName, 'Mean_squared_error': MSE ,'R2_score': R2score,'Mean_absolute_error': MAE,'Cross_val_score':cvs})
result
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
#                   Model_name  Mean_squared_error  R2_score  \
# 0           LinearRegression            0.022760  0.243362
# 1                      Lasso            0.030082 -0.000083
# 2                      Ridge            0.022956  0.236835
# 3                 ElasticNet            0.030082 -0.000083
# 4      DecisionTreeRegressor            0.010311  0.657219
# 5        KNeighborsRegressor            0.009457  0.685617
# 6  GradientBoostingRegressor            0.008040  0.732716
# 7      RandomForestRegressor            0.008019  0.733416
#
#    Mean_absolute_error  Cross_val_score
# 0             0.113399        -0.178296
# 1             0.129219        -0.229263
# 2             0.113917        -0.133884
# 3             0.129219        -0.229263
# 4             0.066086        -0.962744
# 5             0.073474        -0.328936
# 6             0.068171         0.143019
# 7             0.064141        -0.076810

# %% [markdown]
# I choose Randomforestregressor as my final model because it has lowest Mean_squared_error and good R2_score as compared to other model
